# %% [markdown]
# # Clase 6
#
# **Contenido**
# - Preguntas ejercicios anteriores.
# - Terminaciones de los archivos. (.py y .ipynb)
# - Funciones (Repaso)
#   - Funciones con argumentos posicionales indefinidos.
#   - Funciones con argumentos nombrados indefinidos.
# - Ejercicio 87, 88, 94, (100, 102, 103)
# - Archivos y Excepciones (Ejemplos).
#
# ## Tema de estudio
# - Instalar Python y VSCode. (Follow this [Video](https://www.youtube.com/watch?v=cUAK4x_7thA)) Until minute 4:15
# - What is IDE?
# - What is a plugin?
# - What are the top 10 plugins used in VSCode?
#
# ## Ejercicios
# - Usar ChatGPT para crear los ejemplos.
# - 149, 150, 151, 152, 153, 154, 155, 168, 171

# %%
# .ipynb interactive python notebook
# Interactive PYthon NoteBook ipynb
# Hay otra terminacion para scripts
# tiene una terminacion llamada .py PYthon
# Normalmente los notebooks son para exploracion, pruebas de concepto y visualizacion rapida
# Normalmente los scripts son para codigo en produccion

# %%
# Funciones
# se definen y tienen un nombre
# reciben argumentos
# hay dos tipos de argumentos (posicionales y nombrados, positional y keyword)
# pueden retornar o no retornar un valor
# Las funciones reciben los argumentos y los usan como variables dentro de si mismas
# pero estos argumentos no salen de la funcion, lo unico que sale de la funcion
# es lo retornado

# %%
def saludar_y_despedir():
  """
  Las funciones pueden no recibir argumentos
  Esta funcion no retorna nada, pero si tiene dos outputs, que son los dos prints
  """
  print("hola")
  print("chao")

# %%
valor_retornado = saludar_y_despedir()
# Out:
# hola
# chao

# %%
print(valor_retornado) # No retorna nada
# Out:
# None

# %%
def saludar_y_despedir_con_nombre(nombre, apellido = "Restrepo"):
  print(f"Hola {nombre} {apellido}")
  print(f"Chao {nombre} {apellido}")

# %%
saludar_y_despedir_con_nombre("Juan")
# Out:
# Hola Juan Restrepo
# Chao Juan Restrepo

# %%
saludar_y_despedir_con_nombre("Juan", "Arbelaez")
# Out:
# Hola Juan Arbelaez
# Chao Juan Arbelaez

# %%
saludar_y_despedir_con_nombre("Juan", apellido="Saez")
# Out:
# Hola Juan Saez
# Chao Juan Saez

# %%
# required == positional == non-default arguments
# default == keyword arguments

# %%
def llamar_a_la_policia(tel="123"):
  print(f"Llamando al {tel}")

# %%
llamar_a_la_policia()
# Out:
# Llamando al 123

# %%
llamar_a_la_policia("911")
# Out:
# Llamando al 911

# %%
def calculo_2(pi=3.14):
  print(pi*2)

# %%
calculo_2()
# Out:
# 6.28

# %%
from random import randint

print(randint(7, 10))
# Out:
# 8

# %%
# type hinting
# pista del tipo
def sumar_dos_numeros(x: float, y: float):
  return(x + y)

# %%
sumar_dos_numeros()

# %%
def calcular_area(base = 0, altura = 0):
  if base == 0 and altura == 0:
    return "Ingrese base y altura"
  return ((base * altura)/2)

# %%
calcular_area()
# Out:
# 'Ingrese base y altura'

# %%
tupla_1 = ("Hola", "Chao")
print(tupla_1)
print(type(tupla_1))
print(tupla_1[0])
# tupla_1[0] = "Chao1"
# Las tuplas son inmutables
# Out:
# ('Hola', 'Chao')
# <class 'tuple'>
# Hola

# %%
zoo = {1: "Tigre", 102: "Leon", 203: "Oso"}
print(zoo.items()) # ejemplo de uso de las tuplas
# Out:
# dict_items([(1, 'Tigre'), (102, 'Leon'), (203, 'Oso')])

# %% [markdown]
# Exercise 87: Shipping Calculator
# An online retailer provides express shipping for many of its items at a rate of \$10.95 for the first item in an order, and \$2.95 for each subsequent item in the same order.
#
# Write a function that takes the number of items in the order as its only parameter.
#
# Return the shipping charge for the order as the function's result.
#
# Include a main program that reads the number of items purchased from the user and displays the
# shipping charge.

# %%
def calculate_shipping_charge(number_of_items: int) -> float:
  """
  Function to calculate shipping charge, returns 0 if number of items is 0
  :param number_of_items: number of items to calculate the shipping charge
  :return: Cost in float type
  """
  if number_of_items == 0:
    return 0.0
  discounted_number_of_items = number_of_items - 1 # Here we discount the first item
  # Here we add the cost of the first item plus of the resting items
  return 10.95 + discounted_number_of_items * 2.95

# def calculate_shipping_charge_2(number_of_items: int):
#   if number_of_items == 1:
#     return 10.95
#   return 2.95 * (number_of_items - 1) + (10.95 * 1)

# %%
def main_87():
  items = input("Enter the number of items to order ")
  if not(items.isdigit()):
    return "Please, enter a digit"
  int_items = int(items)
  shipping_cost = calculate_shipping_charge(int_items)
  return f"The shipping cost is {shipping_cost: .2f}"

# %%
result = main_87()
print(result)
# Out:
# Enter the number of items to order 2
# The shipping cost is  13.90

# %% [markdown]
# Exercise 88: Median of Three Values
# Write a function that takes three numbers as parameters, and
#
# returns the median value of those parameters as its result.
#
# Include a main program that reads three values from
# the user and displays their median.

# %%
# [1, 2, 3] # mediana = 2
# [5, 10, 8] # mediana = 8
# [5, 6, 7, 8] # mediana = (6 + 7) / 2

# %%
def median_of_three(a: float, b: float, c: float):
  list_of_numbers = [a, b, c]
  list_of_numbers.sort()
  return list_of_numbers[1]

# def median_of_three_2(list_of_numbers: list):
#   if len(list_of_numbers) != 3:
#     return "List has less or more than 3 elements"
#   list_of_numbers.sort()
#   return list_of_numbers[1]

# %%
def main_88():
  number_1 = float(input("Enter the first value "))
  number_2 = float(input("Enter the second value "))
  number_3 = float(input("Enter the third value "))

  result = median_of_three(number_1, number_2, number_3)
  return result
  # numbers = input("Enter the three values separated with comma ")

  # numbers = []
  # for i in range(3):
  #   number = input("Enter a value")
  #   if not(number.isdigit()):
  #     continue
  #   numbers.append(int(number))

  # numbers = []
  # contador = 0
  # while contador < 3:
  #   contador += 1
  #   number = input("Enter a value")
  #   if number.isdigit():
  #     numbers.append(int(number))

# %%
result = main_88()
print(result)
# Out:
# Enter the first value 1
# Enter the second value 2
# Enter the third value 3
# 2.0

# %% [markdown]
# Exercise 94: Is It a Valid Triangle?
#
# If you have 3 straws, possibly of differing lengths, it may or may not be possible to lay them down so that they form a triangle when their ends are touching.
#
# For example, if all of the straws have a length of 6 inches then one can easily construct an equilateral triangle using them.
#
# However, if one straw is 6 inches long, while the other two are each only 2 inches long, then a triangle cannot be formed. More generally, if any one length is greater than or equal to the sum of the other two then
# the lengths cannot be used to form a triangle.
#
# Otherwise they can form a triangle.
#
# Write a function that determines whether or not three lengths can form a triangle.
#
# The function will take 3 parameters and return a Boolean result.
#
# If any of the lengths are less than or equal to 0 then your function should return False.
#
# Otherwise it should determine whether or not the lengths can be used to form a triangle using the method described in the previous paragraph, and return the appropriate result.
#
# In addition, write a program that reads 3 lengths from the user and demonstrates the
# behaviour of your function.

# %%
# 94

def triangle(a: float, b: float, c: float) -> bool:
  if a <= 0 or b <= 0 or c <= 0:
    return False
  if a >= (b + c) or b >= (a + c) or c >= (a + b):
    return False
  return True

def main_94():
  numbers = []
  for n in range(3):
    number = input("Enter a length: ")
    if number.isdigit() or "-" in number:
      numbers.append(float(number))
  if len(numbers) != 3:
    return "There are less or more than 3 lengths"
  if triangle(numbers[0], numbers[1], numbers[2]):
    return f"With these three lengths you can create a triangle {numbers}"
  else:
    return f"With these three lengths you canNOT create a triangle {numbers}"

# %%
message = main_94()
print(message)
# Out:
# Enter a length: -1
# Enter a length: 1
# Enter a length: 2
# With these three lengths you canNOT create a triangle [-1.0, 1.0, 2.0]

# %%
for index in range(3):
  print(index)
# Out:
# 0
# 1
# 2

# %% [markdown]
# Exercise 100: Random Password
# Write a function that generates a random password.
#
# The password should have a random length of between 7 and 10 characters.
#
# Each character should be randomly selected from positions 33 to 126 in the ASCII table.
#
# Your function will not take any parameters.
#
# It will return the randomly generated password as its only result.
#
# Display the randomly generated password in your file's main program.

# %%
from random import randint, choice

def random_password():
  length_of_pass = randint(7, 10)
  # password = [chr(randint(33, 126)) for _ in range(length_of_pass)]
  password = []
  for _ in range(length_of_pass):
    password.append(chr(randint(33, 126)))

  return "".join(password)

# %%
def main_100():
  print(random_password())

# %%
main_100()
# Out:
# 6ClPc>y0;

# %%
print(list("juan"))
# Out:
# ['j', 'u', 'a', 'n']

# %%
nombre = ['j', 'u', 'a', 'n']
print("".join(nombre))
# Out:
# juan

# %%
# con choice
options_for_length = [1, 10, 100, 1000]

print(list(options_for_length))

length_of_pass = choice(options_for_length)
print(length_of_pass)
# Out:
# [1, 10, 100, 1000]
# 100

# %%
# con randint
length_of_pass = randint(1, 1000)
print(length_of_pass)
# Out:
# 226

# %% [markdown]
# Exercise 102: Check a Password
# In this exercise you will write a function that determines whether or not a password is good.
#
# We will define a good password to be a one that is at least 8 characters long and contains at least one uppercase letter, at least one lowercase letter, and at least one number.
#
# Your function should return True if the password passed to it as its only parameter is good.
#
# Otherwise it should return False.
#
# Include a main program that reads a password from the user and reports whether or not it is good.

# %%
def check_password(password: str) -> bool: # Ae123456
  good_password = False # False
  if len(password) >= 8: # len("Ae123456") = 8 -> True
    uppercase = False
    lowercase = False
    contains_number = False
    for letter in password: # [A e 1 2 3 4 5 6] # uppercase = True lowercase = True contains_number = True
      if letter.isupper(): # tercer ciclo letter = 1 # false
        uppercase = True
      elif letter.islower(): # tercer ciclo letter = 1 # false
        lowercase = True
      elif letter.isdigit(): # tercer ciclo letter = 1 # true
        contains_number = True
      elif uppercase and lowercase and contains_number:
        break
    if uppercase and lowercase and contains_number:
      good_password = True
  return good_password # salta hasta aca

# %%
def main_102():
  testpass = input("Ingresa una contraseña ")
  result = check_password(testpass)
  if result:
    print("Password is good")
  else:
    print("Try again")

# %%
main_102()
# Out:
# Ingresa una contraseña ***
# Try again

# %% [markdown]
# Exercise 103: Random Good Password
#
# (22 Lines) Using your solutions to Exercises 100 and 102, write a program that generates a random good password and displays it. Count and display the number of attempts that were needed before a good password was generated. Structure your solution so that it imports the functions you wrote previously and then calls them from a function
# named main in the file that you create for this exercise.

# %%
def main_103():
  bad_password = True
  contador = 0
  while bad_password:
    contador += 1
    print(contador)
    testpass = random_password()
    print(testpass)
    result = check_password(testpass)
    print(result)
    print(f"La contraseña es mala? {bad_password}")
    if result:
      print("La contraseña ya si es buena")
      bad_password = False

  return contador, testpass

# %%
c, p = main_103()
print(c)
print(p)
# Out:
# 1
# \hb+@H-
# False
# La contraseña es mala? True
# 2
# `E?)~/:`
# False
# La contraseña es mala? True
# 3
# *,sk#^#:
# False
# La contraseña es mala? True
# 4
# =>%h'I&C
# False
# La contraseña es mala? True
# 5
# iD)IyepDV]
# False
# La contraseña es mala? True
# 6
# KXNa(QlE
# False
# La contraseña es mala? True
# 7
# K7*12@[HH2
# False
# La contraseña es mala? True
# 8
# wq0Xu8V_J:
# True
# La contraseña es mala? True
# La contraseña ya si es buena
# 8
# wq0Xu8V_J:

# %%
print(len([1, 2]))
# Out:
# 2

# %%
print(len("hola"))
# Out:
# 4
